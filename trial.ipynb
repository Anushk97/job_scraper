# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    search_term="software engineer",
    location="Singapore",
    results_wanted=20,
    hours_old=72, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed='USA',  # only needed for indeed / glassdoor
    
    # linkedin_fetch_description=True # get full description and direct job url for linkedin (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
    
)
print(f"Found {len(jobs)} jobs")
# print(jobs.head())
# jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
jobs.head()
# Out:
# 2024-05-30 01:23:58,168 - JobSpy - INFO - Indeed search page: 1
# 2024-05-30 01:23:58,171 - JobSpy - INFO - LinkedIn search page: 1
# 2024-05-30 01:23:58,558 - JobSpy - INFO - Indeed found no jobs on page: 1
# 2024-05-30 01:23:58,558 - JobSpy - INFO - Indeed finished scraping
# 2024-05-30 01:23:58,563 - JobSpy - INFO - ZipRecruiter search page: 1
# 2024-05-30 01:23:59,027 - JobSpy - INFO - ZipRecruiter finished scraping
# 2024-05-30 01:23:59,421 - JobSpy - INFO - Glassdoor search page: 1
# 2024-05-30 01:24:02,137 - JobSpy - INFO - Glassdoor finished scraping
# 2024-05-30 01:24:02,569 - JobSpy - INFO - LinkedIn search page: 2
# 2024-05-30 01:24:07,439 - JobSpy - INFO - LinkedIn search page: 3
# 2024-05-30 01:24:08,193 - JobSpy - INFO - Linkedin finished scraping
# Found 40 jobs
#               id       site  \
# 0  1009298986880  glassdoor
# 1  1009298987801  glassdoor
# 2  1009298986848  glassdoor
# 4  1009298988440  glassdoor
# 5  1009298986473  glassdoor
#
#                                              job_url job_url_direct  \
# 0  https://www.glassdoor.com/job-listing/j?jl=100...           None
# 1  https://www.glassdoor.com/job-listing/j?jl=100...           None
# 2  https://www.glassdoor.com/job-listing/j?jl=100...           None
# 4  https://www.glassdoor.com/job-listing/j?jl=100...           None
# 5  https://www.glassdoor.com/job-listing/j?jl=100...           None
#
#                                                title    company   location  \
# 0         Software Engineer (JavaScript, TypeScript)  NodeFlair  Singapore
# 1          Software Application Engineer #SGUnitJobs  NodeFlair  Singapore
# 2                           Software Engineer, GenAI  NodeFlair  Singapore
# 4  Junior Software Engineer (Digital Diagnostics)...  NodeFlair  Singapore
# 5                         Software Engineer (Appian)  NodeFlair  Singapore
#
#   job_type date_posted interval  ...  company_url_direct  company_addresses  \
# 0     None  2024-05-30  monthly  ...                None               None
# 1     None  2024-05-30  monthly  ...                None               None
# 2     None  2024-05-30  monthly  ...                None               None
# 4     None  2024-05-30  monthly  ...                None               None
# 5     None  2024-05-30  monthly  ...                None               None
#
#   company_industry company_num_employees company_revenue company_description  \
# 0             None                  None            None                None
# 1             None                  None            None                None
# 2             None                  None            None                None
# 4             None                  None            None                None
# 5             None                  None            None                None
#
#   logo_photo_url banner_photo_url ceo_name ceo_photo_url
# 0           None             None     None          None
# 1           None             None     None          None
# 2           None             None     None          None
# 4           None             None     None          None
# 5           None             None     None          None
#
# [5 rows x 28 columns]

# %%
jobs.columns
# Out:
# Index(['id', 'site', 'job_url', 'job_url_direct', 'title', 'company',
#        'location', 'job_type', 'date_posted', 'interval', 'min_amount',
#        'max_amount', 'currency', 'is_remote', 'job_function', 'emails',
#        'description', 'company_url', 'company_url_direct', 'company_addresses',
#        'company_industry', 'company_num_employees', 'company_revenue',
#        'company_description', 'logo_photo_url', 'banner_photo_url', 'ceo_name',
#        'ceo_photo_url'],
#       dtype='object')
